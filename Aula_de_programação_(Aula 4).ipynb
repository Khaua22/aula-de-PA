# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaua22/aula-de-PA/blob/main/Aula_de_programa%C3%A7%C3%A3o_(Aula%204).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# \# aula de programação e algoritimos
#
# A=s
# B=6
# T=A+B

# %%
#Tipos Numéricos
Idade=25 #int
Altura=1,75 #float
numéro_complexo=2+3j #complex

# %%
# Tipo Texto
nome= "Alice" # str

# %%
# Tipo  Buleano
esta_chovendo = False  #boot

# %%
#tipo lista (mutavel)

numéros = [1,2,3,4,5] #list

# %%
# tipo tupla(imutavel)
cordenandas = (10,20)  #tuple

# %%
# Tipo Conjunto (valores unicos)
vogais = {'a','e','i','o','u'} #set

# %%
# Tipo Dicionario (Chave Valor)
pessoa = {"nome":"carlos","idade": 30} #dict
