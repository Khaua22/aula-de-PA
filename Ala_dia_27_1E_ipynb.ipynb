# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaua22/aula-de-PA/blob/main/Aula_dia_27_1E_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escrever estrutura de decisões(if,elif e else)

# Escrever um programa que 02 numeros

# Entradas
a = int (input("digite um numero inteiro:"))
b = int (input("digite um numero inteiro:"))

# processamento / saída

if a == b:
    print (f"{a} é igual de {b}")

else:
    print (f"{a} é igual de {b}")
# Out:
# digite um numero inteiro:4
# digite um numero inteiro:6
# 4 é igual de 6

# %%
# escrever um programa que verifica se o numero digitado é par ou impar

# Entrada

numero = int (input("Digite um nome: "))

# Processamento / saida

if numero % 2 == 0:

    print (f" O número {numero} é par:")

else:
  print (f"O número {numero} é impar")
# Out:
# digite um nome: khaua
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5719/1515862172.py in <cell line: 0>()
#       3 # Entrada
#       4
# ----> 5 numero = int (input("digite um nome: "))
#       6
#       7 # Processamento / saida
#
# ValueError: invalid literal for int() with base 10: 'khaua'

# %%
# Escrever umj programa que o usuario digita o nome e a idade e verifica se o usuario é criança ou adolecente




nome = str (input("digite o seu nome: "))
idade = int (input("digite o sua idade: "))

# processamento / saida

if idade < 12 :
  print("você é uma criança")

elif idade <18 :
  print("você é um adolecente")

else:

  print ("você é um adulto")
# Out:
# digite o seu nome: khaua
# digite o sua idade: 67
# você é um adulto

# %%
# Escrever um programa de uma calculadora simples. O usurrio ira digitar 02 numeros e escolhera uma operração aritimetica

# Entrada

print ("==========CALCULADORA==========|")
print ("==========MENU==========|")
print("                               |")
print("opção = 1 - Soma               |")
print("opção = 2 - Subtração          |")
print("opção = 3 - Multiplicação      |")
print("opção = 4 - Divisão            |")

# Entrada
numero = float (input("Digite um numero: "))
opcao = int (input("Escolha a opção desejada: "))
numero1 = float(input("digite um numero: "))

# Processamento / saida

if opcao == 1:
  print (f"A soma de {numero} e {numero1} é igual a {numero + numero1}")

elif opcao == 2:
  print (f"A subtração de {numero} e {numero1} é igual a {numero - numero1}")

elif opcao == 3 :
   print (f"A multiplicação de {numero} e {numero1} é igual a {numero * numero1}")

elif opcao == 4 :
   print (f"A divisão de {numero} e {numero1} é igual a {numero / numero1}")










else:
  print ("opção invalida")
# Out:
# ==========CALCULADORA==========|
# ==========MENU==========|
#                                |
# opção = 1 - Soma               |
# opção = 2 - Subtração          |
# opção = 3 - Multiplicação      |
# opção = 4 - Divisão            |
# Digite um numero: 5
# Escolha a opção desejada: 4
# digite um numero: 3
# A divisão de 5.0 e 3.0 é igual a 1.6666666666666667
