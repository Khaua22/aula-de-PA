# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaua22/aula-de-PA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# aula de programação e algoritimos0
A=s
B=6
T=A+B
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2691/778540109.py in <cell line: 0>()
#       1 # aula de programação e algoritimos0
# ----> 2 A=s
#       3 B=6
#       4 T=A+B
#
# NameError: name 's' is not defined

# %%
#Tipos Numéricos
Idade=25 #int
Altura=1,75 #float
numéro_complexo=2+3j #complex

# %%
# Tipo Texto
nome= "Alice" # str

# %%
# Tipo  Buleano
esta_chovendo = False  #boot

# %%
#tipo lista (mutavel)

numéros = [1,2,3,4,5] #list

# %%
# tipo tupla(imutavel)
cordenandas = (10,20)  #tuple

# %%
# Tipo Conjunto (valores unicos)
vogais = {'a','e','i','o','u'} #set

# %%
# Tipo Dicionario (Chave Valor)
pessoa = {"nome":"carlos","idade": 30} #dict
