# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaua22/aula-de-PA/blob/main/hello_word_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello word")
# Out:
# hello word

# %%
from google.colab import drive
drive.mount('/content/drive')
